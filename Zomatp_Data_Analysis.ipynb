# %% [markdown]
#                                                    Zomato Data Analysis Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Zomato data .csv")

# %%
print(df.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# Convert Datatype of a column- rate

# %%
def handleRate (value):
  value=str(value).split('/')
  value=value[0];
  return float(value)
df['rate']=df['rate'].apply(handleRate)
print(df.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.0    775
# 1         Spice Elephant          Yes         No   4.0    787
# 2        San Churro Cafe          Yes         No   3.0    918
# 3  Addhuri Udupi Bhojana           No         No   3.0     88
# 4          Grand Village           No         No   3.0    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# 1) What type of restaurant do the majority of customers order from?

# %%
# Types of Restaurent

# %%
sns.countplot(x=df["listed_in(type)"])
plt.xlabel("Types of Restaurent")
# Out:
# Text(0.5, 0, 'Types of Restaurent')

# %% [markdown]
# Conclusion- The majority of restaurents fall into Dining Category.

# %% [markdown]
# 2) How many votes has each type of restaurant received from customers?

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum() 
result = pd.DataFrame({'votes': grouped_data})
plt.plot(result, c="green", marker="o") 
plt.xlabel("Type of restaurant", c="red", size=20)
plt.ylabel("Votes", c="red", size=20)
# Out:
# Text(0, 0.5, 'Votes')

# %% [markdown]
# 3) What are the ratings that the majority of restaurants have received?

# %%
plt.hist(df["rate"],bins=3)
plt.title("Rating Distribution")
plt.show()

# %% [markdown]
# 4)Zomato has observed that most couples order most of their food online. What is their
# average spending on each order?

# %%
couple_data=df["approx_cost(for two people)"]
sns.countplot(x=couple_data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [raw]
# 5) Which mode (online or offline) has received the maximum rating?

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='online_order', y='rate', data=df)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# 6) Which type of restaurant received more offline orders, so that Zomato can provide those
# customers with some good offers?

# %%
# Create a pivot table (assuming the values you want are numeric, or you can use an aggregation function)
pivot_table = df.pivot_table(index='listed_in(type)', columns='online_order', aggfunc='size', fill_value=0)

# Plotting heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt='d')  # fmt='d' works for integer values
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# Conclusion:- Dining Restaurents primarily accept offline orders ,whereas Cafes primarily receive online orders.This suggests that clients prefer to place orders in person at Restaurent But prefer online ordering at Cafes.
